# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY =

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import collections
import numpy as np
import pandas as pd
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url="https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?API_KEY&start_date=2020-01-01&end_date=2020-01-02"
r=requests.get(url)
json_data=r.json()
print(type(json_data))
# Out:
# <class 'dict'>

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
m = collections.ChainMap(json_data)
print('Keys = {}'.format(list(m.keys())))
print('Values = {}'.format(list(m.values())))
# Out:
# Keys = ['dataset']
# Values = [{'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-12-01T14:48:09.907Z', 'newest_available_date': '2020-12-01', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2020-01-01', 'end_date': '2020-01-02', 'data': [['2020-01-02', 114.0, 114.9, 112.7, 113.8, None, 143464.0, 16291666.0, None, None, None]], 'collapse': None, 'order': None, 'database_id': 6129}]

# %%
df = pd.DataFrame((json_data['dataset']['data']), columns=json_data['dataset']['column_names'])
df
# Out:
#          Date   Open   High    Low  Close Change  Traded Volume    Turnover  \
# 0  2020-01-02  114.0  114.9  112.7  113.8   None       143464.0  16291666.0
#
#   Last Price of the Day Daily Traded Units Daily Turnover
# 0                  None               None           None

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
url="https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?API_KEY&start_date=2017-01-01&end_date=2017-12-31"
r=requests.get(url)
json_data=r.json()
print(type(json_data))
# Out:
# <class 'dict'>

# %%
df = pd.DataFrame((json_data['dataset']['data']), columns=json_data['dataset']['column_names'])
df
# Out:
#            Date   Open   High    Low  Close  Change  Traded Volume   Turnover  \
# 0    2017-12-29  51.76  51.94  51.45  51.76     NaN        34640.0  1792304.0
# 1    2017-12-28  51.65  51.82  51.43  51.60     NaN        40660.0  2099024.0
# 2    2017-12-27  51.45  51.89  50.76  51.82     NaN        57452.0  2957018.0
# 3    2017-12-22  51.05  51.50  50.92  51.32     NaN        71165.0  3641949.0
# 4    2017-12-21  51.16  51.52  50.90  51.40     NaN       120649.0  6179433.0
# ..          ...    ...    ...    ...    ...     ...            ...        ...
# 250  2017-01-06  34.91  35.21  34.91  35.04     NaN        27507.0   964046.0
# 251  2017-01-05  35.02  35.20  34.73  35.06     NaN        48412.0  1692326.0
# 252  2017-01-04  35.48  35.51  34.75  35.19     NaN        54408.0  1906810.0
# 253  2017-01-03  35.90  35.93  35.34  35.48     NaN        70618.0  2515473.0
# 254  2017-01-02  34.99  35.94  34.99  35.80     NaN        44700.0  1590561.0
#
# ...

# %%
df.drop(['Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], axis=1, inplace=True)
df
# Out:
#            Date   Open   High    Low  Close  Change  Traded Volume   Turnover
# 0    2017-12-29  51.76  51.94  51.45  51.76     NaN        34640.0  1792304.0
# 1    2017-12-28  51.65  51.82  51.43  51.60     NaN        40660.0  2099024.0
# 2    2017-12-27  51.45  51.89  50.76  51.82     NaN        57452.0  2957018.0
# 3    2017-12-22  51.05  51.50  50.92  51.32     NaN        71165.0  3641949.0
# 4    2017-12-21  51.16  51.52  50.90  51.40     NaN       120649.0  6179433.0
# ..          ...    ...    ...    ...    ...     ...            ...        ...
# 250  2017-01-06  34.91  35.21  34.91  35.04     NaN        27507.0   964046.0
# 251  2017-01-05  35.02  35.20  34.73  35.06     NaN        48412.0  1692326.0
# 252  2017-01-04  35.48  35.51  34.75  35.19     NaN        54408.0  1906810.0
# 253  2017-01-03  35.90  35.93  35.34  35.48     NaN        70618.0  2515473.0
# 254  2017-01-02  34.99  35.94  34.99  35.80     NaN        44700.0  1590561.0
#
# [255 rows x 8 columns]

# %%
df['Change'] = df.Open - df.Close
df['Changepct'] = ((df.Open - df.Close) / df.Open) * 100
df['DailyChange'] = df.High - df.Low
df['DayToDay'] = df.Close.diff()

# %%
df
# Out:
#            Date   Open   High    Low  Close  Change  Traded Volume   Turnover  \
# 0    2017-12-29  51.76  51.94  51.45  51.76    0.00        34640.0  1792304.0
# 1    2017-12-28  51.65  51.82  51.43  51.60    0.05        40660.0  2099024.0
# 2    2017-12-27  51.45  51.89  50.76  51.82   -0.37        57452.0  2957018.0
# 3    2017-12-22  51.05  51.50  50.92  51.32   -0.27        71165.0  3641949.0
# 4    2017-12-21  51.16  51.52  50.90  51.40   -0.24       120649.0  6179433.0
# ..          ...    ...    ...    ...    ...     ...            ...        ...
# 250  2017-01-06  34.91  35.21  34.91  35.04   -0.13        27507.0   964046.0
# 251  2017-01-05  35.02  35.20  34.73  35.06   -0.04        48412.0  1692326.0
# 252  2017-01-04  35.48  35.51  34.75  35.19    0.29        54408.0  1906810.0
# 253  2017-01-03  35.90  35.93  35.34  35.48    0.42        70618.0  2515473.0
# 254  2017-01-02  34.99  35.94  34.99  35.80   -0.81        44700.0  1590561.0
#
# ...

# %%
print('Max Open:', max(df.Open), '\n' 'Min Open', min(df.Open))
# Out:
# Max Open: 53.11
# Min Open 34.0

# %%
print('Max Change in One Day:', round(max(df.DailyChange),2))
# Out:
# Max Change in One Day: 2.81

# %%
#print('Max Change:', max(df.Change), '\n' 'Max Pct Change:', max(df.Changepct))

# %%
print('Max Change, Day to Day:', round(max(df.DayToDay[df.DayToDay.notnull()]),2))
# Out:
# Max Change, Day to Day: 2.56

# %%
print('Average Daily Trading Volume:', df['Traded Volume'].mean())
# Out:
# Average Daily Trading Volume: 89124.33725490196

# %%
print('Median Daily Trading Volume', df['Traded Volume'].median())
# Out:
# Median Daily Trading Volume 76286.0
